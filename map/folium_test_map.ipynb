# %%
import pandas as pd
import folium
import json
from folium import plugins
import glob

# %%
import os

os.chdir('/Users/alexcoleman/PhD_OneDrive/Code/Python/YO_Floodrisk/')

os.getcwd()
# Out:
# '/Users/alexcoleman/PhD_OneDrive/Code/Python/YO_Floodrisk'

# %%
flood_risk = pd.read_csv(glob.glob('/Users/alexcoleman/PhD_OneDrive/Code/Python/YO_Floodrisk/data/*risk.csv')[0], encoding='latin')

# %%
with open('/Users/alexcoleman/PhD_OneDrive/Code/Python/YO_Floodrisk/data/manipulated_flood_risk.geojson') as f:
    data = json.load(f)

# %%
m = folium.Map(location=[53.752288, -1.677899],
               tiles='OpenStreetMap',
               zoom_start=10)

# %%
folium.GeoJson(
      data=data
      
).add_to(m)

m.add_child(folium.LatLngPopup())
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
